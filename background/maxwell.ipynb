# %% [markdown]
# ## Introduction to the Interstellar Medium
# ### Jonathan Williams

# %% [markdown]
# ### Figure 3.1: Maxwell-Boltzmann velocity distribution for 3 different temperatures

# %%
import sys, os, pdb, glob
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import maxwell
# %matplotlib inline

# %%
nsteps = 300
vmin = 0
vmax = 10
dv = (vmax - vmin)/nsteps
v = np.arange(vmin,vmax,dv)   # km/s
v *= 1000                     # SI

fig = plt.figure(figsize=(6,4))
ax1 = fig.add_axes([0.12,0.14,0.83,0.76])
ax1.set_xlabel(r"$v$ (km/s)", fontsize=16)
ax1.set_ylabel(r"$f(v)$ (km/s)$^{-1}$", fontsize=16)

k_B = 1.3807e-23               # J/K
m_H = 1.6726e-27               # kg
T  = [10,100,1000]             # K
c  = ['blue', 'green', 'red']
ls = ['-', '--', ':']
for i, T1 in enumerate(T):
    a = np.sqrt(k_B * T1 / m_H)
    f = maxwell.pdf(v, scale=a)
    #ax1.plot(v/1000, f, '-', color=c[i], lw=3, label=str("T={0}K".format(T1)))
    ax1.plot(v/1000, f*1000, ls[i], color='k', lw=3, label=str("T={0}K".format(T1)))

ax1.legend(fontsize=10, handlelength=2.5, borderpad=1.0, borderaxespad=1.2)
ax1.set_xlim(0,10)
ax1.set_ylim(0,2.1)

plt.show()
